# %% [markdown]
# # R(4,4) plot

# %% [markdown]
# We plot the Paley graph on 17 vertices, the unique Ramsey critical graph for the Ramsey number R(4,4).

# %% [markdown]
# # Imports

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Creating the graph

# %%
def create_circulant_graph(n: int, distances: list) ->  nx.classes.graph.Graph:
    G = nx.Graph()
    for i in range(n):
        for d in distances:
            G.add_edge(i, (i + d) % n)
    return G

# %%
n = 17  # Nuber of vertices of the graph
distances = [1, 2, 4, 8]

# Create the circulant graph
G = create_circulant_graph(n, distances)

# %% [markdown]
# # The plot

# %%
def circulant_layout(G, distances):
    n = G.number_of_nodes()
    pos = {}
    for i in range(n):
        angle = 2 * np.pi * i / n
        pos[i] = (np.cos(angle), np.sin(angle))
    return pos

# %%
pos = circulant_layout(G, distances)

# Draw the graph
fig, ax = plt.subplots(figsize=(12, 12))
nx.draw(G, pos, ax=ax, with_labels=False, node_color='lightblue', 
        node_size=30, edgecolors='black', linewidths=1)

# Draw edges with different colors for each distance
colors = ['red', 'green', 'blue', 'yellow', 'purple', 'orange', 'pink', 'cyan', 
          'magenta', 'lime', 'brown', 'navy', 'teal', 'olive', 'maroon', 
          '#FF5733', '#33FF57', '#5733FF', '#FF33F1', '#33FFF1']
for i, d in enumerate(distances):
    edge_list = [(j, (j + d) % n) for j in range(n)]
    nx.draw_networkx_edges(G, pos, edgelist=edge_list, edge_color=colors[i], ax=ax)

ax.set_title(f"Circulant Graph on 17 vertices with distances {distances}. This is the unique Ramsey-critical graph for R(4,4)=18. ")
ax.axis('off')
plt.tight_layout()
plt.show()
